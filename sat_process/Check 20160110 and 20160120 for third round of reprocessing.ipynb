# %%
# %matplotlib notebook
import datetime as dt  # Python standard library datetime  module
import numpy as np
import netCDF4  # http://code.google.com/p/netcdf4-python/
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap, addcyclic, shiftgrid

import s2_py as s2
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Polygon, mapping

import os
import pickle
import wget
import subprocess


import matplotlib.animation as animation

import google.cloud.bigquery
import pandas_gbq
import pandas as pd
import shapefile as shp
import descartes
from shapely.geometry import Polygon, mapping, Point
from sklearn.metrics.pairwise import euclidean_distances

import itertools

# %%
# Courtesy Yulia
ca_s2_df = gpd.read_file("/home/scott/w210_Wildfire/DataPrep/Data/Processed/CA_S2Cells/CA_S2Cells.shp")

# %%
ca_s2_df.head()
# Out:
#    CWA                        NAME STATE_ZONE FE_AREA      AREA  WF_cum_are  \
# 0  VEF  Death Valley National Park      CA227      ee  2.001602   37.487592
# 1  VEF  Death Valley National Park      CA227      ee  2.001602   37.487592
# 2  VEF  Death Valley National Park      CA227      ee  2.001602   37.487592
# 3  VEF  Death Valley National Park      CA227      ee  2.001602   37.487592
# 4  VEF  Death Valley National Park      CA227      ee  2.001602   37.487592
#
#   FZ_grp S2_Cells_I                                           geometry
# 0    low     80b8a4  POLYGON ((-116.9852421934208 36.92851788893871...
# 1    low     80b8ac  POLYGON ((-117.1735315927328 36.88229296981148...
# 2    low     80b8b4  POLYGON ((-117.1735315927328 37.04169221702246...
# 3    low     80be44  POLYGON ((-118.2994349957241 37.38986432048104...
# 4    low     80be4c  POLYGON ((-118.2994349957241 37.23225420438236...

# %%
len(ca_s2_df)
# Out:
# 10643

# %%
data_dir = '/home/scott/sat_aggs/'
csvfiles = {}
for dirpath, dirnames, filenames in os.walk(data_dir):
    for filename in [f for f in filenames if f.endswith(".csv")]:
        csvfiles[filename] = (os.path.join(dirpath, filename))

# %%
csvfiles.keys()
# Out:
# dict_keys(['20160110_agg.csv', '20160120_agg.csv', '20160820_agg_date.csv', '20161031_agg_date_date.csv', '20160510_agg_date.csv', '20160131_agg_date.csv', '20160120_agg_date.csv', '20160310_agg_date.csv', 'fapar2016_v2.csv', 'fapar2016_v2_date.csv', '20160110_agg_date.csv', '20160520_agg_date.csv', 'fapar2016_date.csv', '20160620_agg_date.csv', '20160610_agg_date.csv', '20161031_agg_date.csv', 'fapar2018.csv', 'fapar2016.csv', '20160331_agg_date.csv', '20161130_agg_date.csv', '20160710_agg_date.csv', '20161120_agg_date.csv', '20160731_agg_date.csv', '20161020_agg_date.csv', '20160531_agg_date.csv', '20160630_agg_date.csv', '20161220_agg_date.csv', '20160210_agg_date.csv', '20161010_agg_date.csv', '20161210_agg_date.csv', '20161231_agg_date.csv', '20160220_agg_date.csv', '20160930_agg_date.csv', '20160430_agg_date.csv', '20160910_agg_date.csv', '20160420_agg_date.csv', '20160229_agg_date.csv', '20160720_agg_date.csv', 'fapar2017.csv', '20160831_agg_date.csv', '20160810_agg_date.csv',
# ...

# %%
file = '20160110_agg.csv'

# %%
year = 2016
dateStart = file.find(str(year))
date = file[dateStart:dateStart+8]
date
# Out:
# '20160110'

# %%
#df['date'] = date[0:4] + '-' + date[5:7] + '-' + date[7:]
dateFormatted = date[0:4] + '-' + date[4:6] + '-' + date[6:]
dateFormatted
# Out:
# '2016-01-10'

# %%
df = pd.read_csv(csvfiles[file])
df['date'] = dateFormatted
df.head()
# Out:
#    Unnamed: 0 mergeKey    lat_min    lat_max   lat_mean  lat_median   lat_std  \
# 0           0   54c934  41.958333  42.053571  42.018738   42.020833  0.022960
# 1           1  54c9354  41.958333  41.997024  41.978733   41.979167  0.009036
# 2           2  54c935c  41.973214  42.011905  41.993210   41.994048  0.009065
# 3           3  54c9364  41.988095  42.026786  42.007709   42.008929  0.009110
# 4           4  54c9414  41.988095  42.029762  42.008885   42.008929  0.009139
#
#    lat_size  lat_count  lat_nunique  ...  faparMask_nunique  faparVal_size  \
# 0      2023       2023           33  ...                  2           2023
# 1       206        206           14  ...                  2            206
# 2       206        206           14  ...                  2            206
# 3       205        205           14  ...                  2            205
# 4       206        206           15  ...                  2            206
#
# ...

# %%
df2 = df.drop(['Unnamed: 0'], axis =1)

# %%
df2.head()
# Out:
#   mergeKey    lat_min    lat_max   lat_mean  lat_median   lat_std  lat_size  \
# 0   54c934  41.958333  42.053571  42.018738   42.020833  0.022960      2023
# 1  54c9354  41.958333  41.997024  41.978733   41.979167  0.009036       206
# 2  54c935c  41.973214  42.011905  41.993210   41.994048  0.009065       206
# 3  54c9364  41.988095  42.026786  42.007709   42.008929  0.009110       205
# 4  54c9414  41.988095  42.029762  42.008885   42.008929  0.009139       206
#
#    lat_count  lat_nunique     lon_min  ...  faparMask_nunique  faparVal_size  \
# 0       2023           33 -121.610119  ...                  2           2023
# 1        206           14 -121.526786  ...                  2            206
# 2        206           14 -121.479167  ...                  2            206
# 3        205           14 -121.431548  ...                  2            205
# 4        206           15 -121.172619  ...                  2            206
#
# ...

# %%
df2.dtypes
# Out:
# mergeKey              object
# lat_min              float64
# lat_max              float64
# lat_mean             float64
# lat_median           float64
# lat_std              float64
# lat_size               int64
# lat_count              int64
# lat_nunique            int64
# lon_min              float64
# lon_max              float64
# lon_mean             float64
# lon_median           float64
# lon_std              float64
# lon_size               int64
# lon_count              int64
# lon_nunique            int64
# faparMask_min           bool
# faparMask_max           bool
# faparMask_mean       float64
# faparMask_median        bool
# faparMask_std        float64
# faparMask_size         int64
# faparMask_count        int64
# faparMask_nunique      int64
# faparVal_size          int64
# faparVal_count         int64
# faparVal_nunique       int64
# faparVal_myMean       object
# faparVal_myMedian     object
# faparVal_myStd        object
# faparVal_min          object
# ...

# %%
df2.replace('--', np.nan, inplace = True)

# %%
df2['faparVal_myMean'].isna().sum()
# Out:
# 43

# %%
df2[df2['faparVal_myMean'].isna()]
# Out:
#      mergeKey    lat_min    lat_max   lat_mean  lat_median   lat_std  \
# 6     54c942c  41.946429  41.985119  41.966899   41.967262  0.009145
# 8     54c943c  41.961310  42.000000  41.980757   41.982143  0.009069
# 33    54c9504  41.863095  41.901786  41.882140   41.880952  0.009081
# 34    54c950c  41.836310  41.875000  41.854284   41.854167  0.009050
# 35    54c9514  41.821429  41.860119  41.840015   41.839286  0.009037
# 40    54c953c  41.806548  41.845238  41.825798   41.824405  0.009042
# 47    54c9574  41.806548  41.845238  41.826296   41.827381  0.009034
# 49    54c9584  41.794643  41.830357  41.812500   41.812500  0.009015
# 50    54c958c  41.806548  41.845238  41.826476   41.827381  0.009074
# 53    54c95a4  41.848214  41.886905  41.868417   41.869048  0.009089
# 55    54c95b4  41.889881  41.928571  41.910392   41.910714  0.008996
# 56    54c95bc  41.863095  41.901786  41.882528   41.882440  0.009145
# 57    54c95c4  41.877976  41.916667  41.896738   41.895833  0.009074
# ...

# %%
(df2['faparVal_myMean']==0).sum()
# Out:
# 0

# %%
(df2['faparVal_myMedian']==0).sum()
# Out:
# 0

# %%
df2[df2['faparVal_myMedian'].isna()]
# Out:
#      mergeKey    lat_min    lat_max   lat_mean  lat_median   lat_std  \
# 6     54c942c  41.946429  41.985119  41.966899   41.967262  0.009145
# 8     54c943c  41.961310  42.000000  41.980757   41.982143  0.009069
# 33    54c9504  41.863095  41.901786  41.882140   41.880952  0.009081
# 34    54c950c  41.836310  41.875000  41.854284   41.854167  0.009050
# 35    54c9514  41.821429  41.860119  41.840015   41.839286  0.009037
# 40    54c953c  41.806548  41.845238  41.825798   41.824405  0.009042
# 47    54c9574  41.806548  41.845238  41.826296   41.827381  0.009034
# 49    54c9584  41.794643  41.830357  41.812500   41.812500  0.009015
# 50    54c958c  41.806548  41.845238  41.826476   41.827381  0.009074
# 53    54c95a4  41.848214  41.886905  41.868417   41.869048  0.009089
# 55    54c95b4  41.889881  41.928571  41.910392   41.910714  0.008996
# 56    54c95bc  41.863095  41.901786  41.882528   41.882440  0.009145
# 57    54c95c4  41.877976  41.916667  41.896738   41.895833  0.009074
# ...

# %%
df2['faparVal_myMean'].isna().sum()
# Out:
# 43

# %%
ca_s2_df[ca_s2_df['S2_Cells_I']=='8085fc']
# Out:
#      CWA           NAME STATE_ZONE FE_AREA      AREA  WF_cum_are FZ_grp  \
# 479  MTR  San Francisco      CA006      ww  0.012579         0.0    low
#
#     S2_Cells_I                                           geometry
# 479     8085fc  POLYGON ((-123.0789010480611 37.7189473593804,...

# %%
# But if I look at the mins, maxes
df2['faparVal_min'].isna().sum()
# Out:
# 43

# %%
df2['faparVal_max'].isna().sum()
# Out:
# 43

# %%
(df2['faparVal_min']==0).sum()
# Out:
# 0

# %%
# not as likely
(df2['faparVal_max']==0).sum()
# Out:
# 0

# %%
ca_s2_df['mergeKey'] = ca_s2_df['S2_Cells_I']
df3 = ca_s2_df.merge(df2, on = 'mergeKey')

# %%
df3['faparVal_myMean'] = df3['faparVal_myMean'].astype('float64')
df3.plot(column = 'faparVal_myMean', legend = True)#, label = 'Mean FAPAR', legend = True)
plt.title('Mean of FAPAR')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Mean of FAPAR')

# %%
df3['faparVal_min'] = df3['faparVal_min'].astype('float64')
df3.plot(column = 'faparVal_min', legend = True)#, label = 'Mean FAPAR', legend = True)
plt.title('Min of FAPAR')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Min of FAPAR')

# %%
df3['faparVal_max'] = df3['faparVal_max'].astype('float64')
df3.plot(column = 'faparVal_max', legend = True)#, label = 'Mean FAPAR', legend = True)
plt.title('Max of FAPAR')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Max of FAPAR')

# %% [markdown]
# ### Now do 20160120

# %%
file = '20160120_agg.csv'

# %%
year = 2016
dateStart = file.find(str(year))
date = file[dateStart:dateStart+8]
date
# Out:
# '20160120'

# %%
#df['date'] = date[0:4] + '-' + date[5:7] + '-' + date[7:]
dateFormatted = date[0:4] + '-' + date[4:6] + '-' + date[6:]
dateFormatted
# Out:
# '2016-01-20'

# %%
df = pd.read_csv(csvfiles[file])
#df['date'] = dateFormatted
df2 = df.drop(['Unnamed: 0'], axis =1)
df2.head()
# Out:
#   mergeKey    lat_min    lat_max   lat_mean  lat_median   lat_std  lat_size  \
# 0   54c934  41.958333  42.053571  42.018738   42.020833  0.022960      2023
# 1  54c9354  41.958333  41.997024  41.978733   41.979167  0.009036       206
# 2  54c935c  41.973214  42.011905  41.993210   41.994048  0.009065       206
# 3  54c9364  41.988095  42.026786  42.007709   42.008929  0.009110       205
# 4  54c9414  41.988095  42.029762  42.008885   42.008929  0.009139       206
#
#    lat_count  lat_nunique     lon_min  ...  faparMask_nunique  faparVal_size  \
# 0       2023           33 -121.610119  ...                  2           2023
# 1        206           14 -121.526786  ...                  1            206
# 2        206           14 -121.479167  ...                  1            206
# 3        205           14 -121.431548  ...                  1            205
# 4        206           15 -121.172619  ...                  2            206
#
# ...

# %%
df2.replace('--', np.nan, inplace = True)

# %%
df2['faparVal_myMean'].isna().sum()
# Out:
# 9

# %%
df2[df2['faparVal_myMean'].isna()]
# Out:
#      mergeKey    lat_min    lat_max   lat_mean  lat_median   lat_std  \
# 90    54c97cc  41.934524  41.973214  41.952921   41.952381  0.009234
# 106   54ca24c  41.916667  41.955357  41.935682   41.934524  0.009109
# 192    54cb53  40.875000  40.955357  40.915370   40.916667  0.017732
# 3916   8085fc  37.568452  37.773810  37.671448   37.672619  0.046907
# 5885  8096664  37.681548  37.729167  37.704332   37.705357  0.011832
# 6217  809713c  38.187500  38.235119  38.210119   38.211310  0.011775
# 6301  80973d4  38.071429  38.119048  38.094048   38.095238  0.011775
# 7382   809e03  40.803571  40.898810  40.850572   40.851190  0.022667
# 7630  80bfe94  36.642857  36.690476  36.667560   36.666667  0.011953
#
#       lat_size  lat_count  lat_nunique     lon_min  ...  faparMask_nunique  \
# 90         204        204           14 -120.717262  ...                  1
# 106        203        203           14 -120.125000  ...                  1
# ...

# %%
(df2['faparVal_myMean']==0).sum()
# Out:
# 0

# %%
(df2['faparVal_min']=='0.0').sum()
# Out:
# 518

# %%
(df2['faparVal_max']=='0.0').sum()
# Out:
# 0

# %%
ca_s2_df['mergeKey'] = ca_s2_df['S2_Cells_I']
df3 = ca_s2_df.merge(df2, on = 'mergeKey')
df3['faparVal_myMean'] = df3['faparVal_myMean'].astype('float64')
df3.plot(column = 'faparVal_myMean', legend = True)#, label = 'Mean FAPAR', legend = True)
plt.title('Mean of FAPAR')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Mean of FAPAR')

# %%
df3['faparVal_min'] = df3['faparVal_min'].astype('float64')
df3.plot(column = 'faparVal_min', legend = True)#, label = 'Mean FAPAR', legend = True)
plt.title('Min of FAPAR')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Min of FAPAR')

# %%
df3['faparVal_max'] = df3['faparVal_max'].astype('float64')
df3.plot(column = 'faparVal_max', legend = True)#, label = 'Mean FAPAR', legend = True)
plt.title('Max of FAPAR')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Max of FAPAR')

# %%
df_20160110 = pd.read_csv(csvfiles['20160110_agg.csv'])
df_20160110 = df_20160110.drop(['Unnamed: 0'], axis =1)
df_20160110.replace('--', np.nan, inplace = True)
ca_s2_df['mergeKey'] = ca_s2_df['S2_Cells_I']
df_20160110 = ca_s2_df.merge(df_20160110, on = 'mergeKey')
df_20160110['faparVal_myMean'] = df_20160110['faparVal_myMean'].astype('float64')
df_20160110.plot(column = 'faparVal_myMean', legend = True)#, label = 'Mean FAPAR', legend = True)
plt.title('Mean of FAPAR, 20160110')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Mean of FAPAR, 20160110')

# %%
df_20160120 = pd.read_csv(csvfiles['20160120_agg.csv'])
df_20160120 = df_20160120.drop(['Unnamed: 0'], axis =1)
df_20160120.replace('--', np.nan, inplace = True)
ca_s2_df['mergeKey'] = ca_s2_df['S2_Cells_I']
df_20160120 = ca_s2_df.merge(df_20160120, on = 'mergeKey')
df_20160120['faparVal_myMean'] = df_20160120['faparVal_myMean'].astype('float64')
df_20160120.plot(column = 'faparVal_myMean', legend = True)#, label = 'Mean FAPAR', legend = True)
plt.title('Mean of FAPAR, 20160120')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Mean of FAPAR, 20160120')

# %%
df_both = df_20160110.merge(df_20160120, on = 'mergeKey')

# %%
df_both['deltaFapar'] = df_both['faparVal_myMean_x'] - df_both['faparVal_myMean_y']

# %%
df_both = gpd.GeoDataFrame(df_both)

# %%
df_both['geometry'] =  df_both['geometry_x']

# %%
df_both.plot(column = 'deltaFapar', legend = True)
plt.title('Change in FAPAR 20160110 to 20160120')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Change in FAPAR 20160110 to 20160120')

# %% [raw]
# # then bash
# awk '(NR == 1) || (FNR > 1)' 2016*.csv > fapar2016.csv
# awk '(NR == 1) || (FNR > 1)' 2017*.csv > fapar2017.csv
# awk '(NR == 1) || (FNR > 1)' 2018*.csv > fapar2018.csv
